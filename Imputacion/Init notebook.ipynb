# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting pyjanitor
#   Downloading pyjanitor-0.24.0-py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.4/158.4 KB 26.2 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 2)) (3.6.0)
# Collecting missingno
#   Downloading missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: numpy in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 4)) (1.23.4)
# Requirement already satisfied: pandas in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 5)) (1.2.5)
# Collecting pandas-flavor
#   Downloading pandas_flavor-0.3.0-py3-none-any.whl (6.3 kB)
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.6.2-py2.py3-none-any.whl (328 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.7/328.7 KB 61.3 MB/s eta 0:00:00
# Requirement already satisfied: seaborn in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 8)) (0.12.1)
# Collecting session-info
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ipywidgets
#   Downloading ipywidgets-8.0.4-py3-none-any.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.8/137.8 KB 32.7 MB/s eta 0:00:00
# Collecting ozon3
#   Downloading ozon3-4.0.1-py3-none-any.whl (27 kB)
# Collecting pyreadr
#   Downloading pyreadr-0.4.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.3/365.3 KB 50.1 MB/s eta 0:00:00
# Collecting upsetplot
#   Downloading UpSetPlot-0.8.0.tar.gz (22 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting statsmodels==0.13.2
#   Downloading statsmodels-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 84.9 MB/s eta 0:00:00
# Collecting nhanes==0.5.1
#   Downloading nhanes-0.5.1-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 99.9 MB/s eta 0:00:00
# Collecting fancyimpute
#   Downloading fancyimpute-0.7.0.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: scipy in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 23)) (1.9.3)
# Collecting sklearn
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: packaging>=21.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from statsmodels==0.13.2->-r ./requirements.txt (line 14)) (21.3)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 KB 38.5 MB/s eta 0:00:00
# Collecting natsort
#   Downloading natsort-8.2.0-py3-none-any.whl (37 kB)
# Collecting multipledispatch
#   Downloading multipledispatch-0.6.0-py3-none-any.whl (11 kB)
# Collecting lazy-loader
#   Downloading lazy_loader-0.1-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (4.37.4)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas->-r ./requirements.txt (line 5)) (2022.5)
#   Downloading lazy_loader-0.1rc2-py3-none-any.whl (5.1 kB)
# Collecting xarray
#   Downloading xarray-2023.1.0-py3-none-any.whl (973 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.1/973.1 KB 120.8 MB/s eta 0:00:00
# Collecting PyYAML<6.1,>=5.0.0
#   Downloading PyYAML-6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.8/661.8 KB 73.6 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas-profiling->-r ./requirements.txt (line 7)) (1.10.2)
# Collecting htmlmin==0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting visions[type_image_path]==0.7.5
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 KB 24.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas-profiling->-r ./requirements.txt (line 7)) (4.64.1)
# Collecting typeguard<2.14,>=2.13.2
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: requests<2.29,>=2.24.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas-profiling->-r ./requirements.txt (line 7)) (2.28.1)
# Collecting phik<0.13,>=0.11.1
#   Downloading phik-0.12.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (679 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.8/679.8 KB 75.4 MB/s eta 0:00:00
# Collecting multimethod<1.10,>=1.4
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas-profiling->-r ./requirements.txt (line 7)) (2.11.3)
# Collecting tangled-up-in-unicode>=0.0.4
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 145.6 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from visions[type_image_path]==0.7.5->pandas-profiling->-r ./requirements.txt (line 7)) (22.1.0)
# Collecting networkx>=2.4
#   Downloading networkx-3.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 103.1 MB/s eta 0:00:00
# Collecting imagehash
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 KB 69.4 MB/s eta 0:00:00
# Collecting stdlib_list
#   Downloading stdlib_list-0.8.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 KB 16.7 MB/s eta 0:00:00
# Collecting widgetsnbextension~=4.0
#   Downloading widgetsnbextension-4.0.5-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 129.5 MB/s eta 0:00:00
# Requirement already satisfied: ipykernel>=4.5.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipywidgets->-r ./requirements.txt (line 10)) (6.16.1)
# Requirement already satisfied: traitlets>=4.3.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipywidgets->-r ./requirements.txt (line 10)) (5.5.0)
# Collecting jupyterlab-widgets~=3.0
#   Downloading jupyterlab_widgets-3.0.5-py3-none-any.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.3/384.3 KB 62.2 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=6.1.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipywidgets->-r ./requirements.txt (line 10)) (8.5.0)
# Collecting sseclient-py
#   Downloading sseclient_py-1.7.2-py2.py3-none-any.whl (8.4 kB)
# Collecting openpyxl
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 KB 42.6 MB/s eta 0:00:00
# Collecting ratelimit
#   Downloading ratelimit-2.2.1.tar.gz (5.3 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting js2py
#   Downloading Js2Py-0.74-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 99.7 MB/s eta 0:00:00
# Collecting knnimpute>=0.1.0
#   Downloading knnimpute-0.1.0.tar.gz (8.3 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: scikit-learn>=0.24.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from fancyimpute->-r ./requirements.txt (line 17)) (1.1.2)
# Collecting cvxpy
#   Downloading cvxpy-1.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 112.2 MB/s eta 0:00:00
# Collecting cvxopt
#   Downloading cvxopt-1.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 91.6 MB/s eta 0:00:00
# Collecting pytest
#   Downloading pytest-7.2.1-py3-none-any.whl (317 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 KB 60.2 MB/s eta 0:00:00
# Collecting nose
#   Downloading nose-1.3.7-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 KB 41.8 MB/s eta 0:00:00
# Requirement already satisfied: tornado>=6.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 10)) (6.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 10)) (7.4.3)
# Requirement already satisfied: pyzmq>=17 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 10)) (24.0.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 10)) (0.1.6)
# Requirement already satisfied: debugpy>=1.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 10)) (1.6.3)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 10)) (1.5.6)
# Requirement already satisfied: psutil in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 10)) (5.9.3)
# Requirement already satisfied: backcall in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: stack-data in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 10)) (0.5.1)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 10)) (4.8.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 10)) (3.0.31)
# Requirement already satisfied: decorator in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 10)) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 10)) (2.13.0)
# Requirement already satisfied: pickleshare in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 10)) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 10)) (0.17.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2<3.2,>=2.11.1->pandas-profiling->-r ./requirements.txt (line 7)) (2.0.1)
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from knnimpute>=0.1.0->fancyimpute->-r ./requirements.txt (line 17)) (1.16.0)
# Requirement already satisfied: joblib>=0.14.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from phik<0.13,>=0.11.1->pandas-profiling->-r ./requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pydantic<1.11,>=1.8.1->pandas-profiling->-r ./requirements.txt (line 7)) (4.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->pandas-profiling->-r ./requirements.txt (line 7)) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->pandas-profiling->-r ./requirements.txt (line 7)) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->pandas-profiling->-r ./requirements.txt (line 7)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->pandas-profiling->-r ./requirements.txt (line 7)) (2022.9.24)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=0.24.2->fancyimpute->-r ./requirements.txt (line 17)) (3.1.0)
# Collecting osqp>=0.4.1
#   Downloading osqp-0.6.2.post8-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 KB 43.3 MB/s eta 0:00:00
# Collecting scs>=1.1.6
#   Downloading scs-3.2.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 132.7 MB/s eta 0:00:00
# Collecting ecos>=2
#   Downloading ecos-2.0.12-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.1/220.1 KB 40.9 MB/s eta 0:00:00
# Requirement already satisfied: setuptools<=64.0.2 in /root/venv/lib/python3.9/site-packages (from cvxpy->fancyimpute->-r ./requirements.txt (line 17)) (58.1.0)
# Collecting pyjsparser>=2.5.1
#   Downloading pyjsparser-2.7.1.tar.gz (24 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tzlocal>=1.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from js2py->ozon3->-r ./requirements.txt (line 11)) (4.2)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Collecting iniconfig
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting exceptiongroup>=1.0.0rc8
#   Downloading exceptiongroup-1.1.0-py3-none-any.whl (14 kB)
# Collecting tomli>=1.0.0
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pytest->fancyimpute->-r ./requirements.txt (line 17)) (1.0.0)
# Collecting pandas
#   Downloading pandas-1.5.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 113.9 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 10)) (0.7.1)
# Requirement already satisfied: jupyter-core>=4.9.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 10)) (4.11.2)
# Requirement already satisfied: entrypoints in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 10)) (0.4)
# Collecting qdldl
#   Downloading qdldl-0.1.5.post3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 98.3 MB/s eta 0:00:00
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 10)) (0.2.5)
# Requirement already satisfied: pytz-deprecation-shim in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tzlocal>=1.2->js2py->ozon3->-r ./requirements.txt (line 11)) (0.1.0.post0)
# Collecting PyWavelets
#   Downloading PyWavelets-1.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 155.6 MB/s eta 0:00:00
# Requirement already satisfied: executing in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 10)) (1.1.1)
# Requirement already satisfied: asttokens in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 10)) (2.0.8)
# Requirement already satisfied: pure-eval in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 10)) (0.2.2)
# Requirement already satisfied: tzdata in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pytz-deprecation-shim->tzlocal>=1.2->js2py->ozon3->-r ./requirements.txt (line 11)) (2022.5)
# Building wheels for collected packages: htmlmin, session-info, upsetplot, fancyimpute, sklearn, knnimpute, ratelimit, pyjsparser
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27098 sha256=65936697dbe63d82408097bc7a13b4431e010250459fd9e9da4be29b66667299
#   Stored in directory: /root/.cache/pip/wheels/1d/05/04/c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
#   Building wheel for session-info (setup.py): started
#   Building wheel for session-info (setup.py): finished with status 'done'
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8048 sha256=446e863a43cb99dcd95b5d6669ffa0a14e2d04237b1c95103dbb62faa81a44e7
#   Stored in directory: /root/.cache/pip/wheels/d4/fc/2e/00ca60bac7954b84907efd41baa9b4853500eaeec4228410c6
#   Building wheel for upsetplot (setup.py): started
#   Building wheel for upsetplot (setup.py): finished with status 'done'
#   Created wheel for upsetplot: filename=UpSetPlot-0.8.0-py3-none-any.whl size=23550 sha256=3f37f34e10236c822250510b34789b00a47e530375d4e2989ce0f4838e9a5d7a
#   Stored in directory: /root/.cache/pip/wheels/e2/6f/1d/2d6fe3ae1a2907eea035ea8e1d27b8f8de1ede6ad268c2be5c
#   Building wheel for fancyimpute (setup.py): started
#   Building wheel for fancyimpute (setup.py): finished with status 'done'
#   Created wheel for fancyimpute: filename=fancyimpute-0.7.0-py3-none-any.whl size=29899 sha256=4723f79f7f374d04c5cd92827694ee97dce2cb9a37af74d56987ab2b2ba94551
#   Stored in directory: /root/.cache/pip/wheels/f9/fc/6a/b0406b906bce293abe23c3b6da5a72637d2d04146ef1125a0b
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2344 sha256=37b876d73a8aa767c03f08e5213d25b5224f7445ff3e0c7c923b3b3eb41b22a6
#   Stored in directory: /root/.cache/pip/wheels/f8/e0/3d/9d0c2020c44a519b9f02ab4fa6d2a4a996c98d79ab2f569fa1
#   Building wheel for knnimpute (setup.py): started
#   Building wheel for knnimpute (setup.py): finished with status 'done'
#   Created wheel for knnimpute: filename=knnimpute-0.1.0-py3-none-any.whl size=11353 sha256=2b634edf77f32a25120a29a69fde115ebb7921606eb67bfd9d236f1b89168023
#   Stored in directory: /root/.cache/pip/wheels/88/c4/be/e232c750d9bc360abf9a5e2cafe0d3e08e3605d2801bb11684
#   Building wheel for ratelimit (setup.py): started
#   Building wheel for ratelimit (setup.py): finished with status 'done'
#   Created wheel for ratelimit: filename=ratelimit-2.2.1-py3-none-any.whl size=5908 sha256=8d84c0a2d4d4cd058e5444e52f0a4095dab8c7fc25231e6ca8e9bf790decc144
#   Stored in directory: /root/.cache/pip/wheels/14/1e/97/126009a0884bdf7e26436cace73d9a4f4596dada4fdc4950ce
#   Building wheel for pyjsparser (setup.py): started
#   Building wheel for pyjsparser (setup.py): finished with status 'done'
#   Created wheel for pyjsparser: filename=pyjsparser-2.7.1-py3-none-any.whl size=26000 sha256=ff666508c7d53b09d681f88d2974b91cbf1361e0f0d46c913e46171a34393f5e
#   Stored in directory: /root/.cache/pip/wheels/f0/70/61/f42dc45dcf0fbe8c495ce579b04730787081499bfb5b8bc60e
# Successfully built htmlmin session-info upsetplot fancyimpute sklearn knnimpute ratelimit pyjsparser
# Installing collected packages: stdlib_list, sseclient-py, sklearn, ratelimit, pyjsparser, nose, nhanes, htmlmin, widgetsnbextension, typeguard, tomli, tangled-up-in-unicode, session-info, PyYAML, PyWavelets, patsy, networkx, natsort, multipledispatch, multimethod, lazy-loader, knnimpute, jupyterlab-widgets, iniconfig, exceptiongroup, et-xmlfile, cvxopt, scs, qdldl, pytest, pandas, openpyxl, imagehash, ecos, xarray, visions, upsetplot, statsmodels, pyreadr, phik, osqp, js2py, pandas-flavor, ozon3, missingno, cvxpy, pyjanitor, pandas-profiling, ipywidgets, fancyimpute
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.5
#     Not uninstalling pandas at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'pandas'. No files were found to uninstall.
# Successfully installed PyWavelets-1.4.1 PyYAML-6.0 cvxopt-1.3.0 cvxpy-1.3.0 ecos-2.0.12 et-xmlfile-1.1.0 exceptiongroup-1.1.0 fancyimpute-0.7.0 htmlmin-0.1.12 imagehash-4.3.1 iniconfig-2.0.0 ipywidgets-8.0.4 js2py-0.74 jupyterlab-widgets-3.0.5 knnimpute-0.1.0 lazy-loader-0.1rc2 missingno-0.5.1 multimethod-1.9.1 multipledispatch-0.6.0 natsort-8.2.0 networkx-3.0 nhanes-0.5.1 nose-1.3.7 openpyxl-3.0.10 osqp-0.6.2.post8 ozon3-4.0.1 pandas-1.5.3 pandas-flavor-0.3.0 pandas-profiling-3.6.2 patsy-0.5.3 phik-0.12.3 pyjanitor-0.24.0 pyjsparser-2.7.1 pyreadr-0.4.7 pytest-7.2.1 qdldl-0.1.5.post3 ratelimit-2.2.1 scs-3.2.2 session-info-1.0.0 sklearn-0.0.post1 sseclient-py-1.7.2 statsmodels-0.13.2 stdlib_list-0.8.0 tangled-up-in-unicode-0.2.0 tomli-2.0.1 typeguard-2.13.3 upsetplot-0.8.0 visions-0.7.5 widgetsnbextension-4.0.5 xarray-2023.1.0
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=bdf84ff9-f66c-44c7-a67c-ca1115a2b683' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
